# %%
from ultralytics import YOLO
import matplotlib.pyplot as plt

# %%
model = YOLO('yolov8n.pt')

# %%
results = model(source="D:\\ComputerVision\\Practical Exam Task\\Detection\\image(1).jpg", show=True, conf=0.4, save=True)
# Out:
# image 1/1 D:\ComputerVision\Practical Exam Task\Detection\image(1).jpg: 352x640 8 persons, 9 cars, 1 bus, 2 trucks, 138.9ms
# Speed: 4.0ms preprocess, 138.9ms inference, 2.5ms postprocess per image at shape (1, 3, 352, 640)
# Results saved to runs\detect\predict9
